# %%
# %matplotlib inline
from nuscenes.nuscenes import NuScenes

nusc = NuScenes(version='v1.0-mini', dataroot='../../data/nuscenes', verbose=True)
# Out:
# ...
# Loading NuScenes tables for version v1.0-mini...
# 23 category,
# 8 attribute,
# 4 visibility,
# 911 instance,
# 12 sensor,
# 120 calibrated_sensor,
# 31206 ego_pose,
# 8 log,
# 10 scene,
# 404 sample,
# 31206 sample_data,
# 18538 sample_annotation,
# 4 map,
# Done loading in 0.673 seconds.
# ...
# Reverse indexing ...
# Done reverse indexing in 0.1 seconds.
# ...

# %%
nusc.list_scenes()
# Out:
# scene-0061, Parked truck, construction, intersectio... [18-07-24 03:28:47]   19s, singapore-onenorth, #anns:4622
# scene-0103, Many peds right, wait for turning car, ... [18-08-01 19:26:43]   19s, boston-seaport, #anns:2046
# scene-0655, Parking lot, parked cars, jaywalker, be... [18-08-27 15:51:32]   20s, boston-seaport, #anns:2332
# scene-0553, Wait at intersection, bicycle, large tr... [18-08-28 20:48:16]   20s, boston-seaport, #anns:1950
# scene-0757, Arrive at busy intersection, bus, wait ... [18-08-30 19:25:08]   20s, boston-seaport, #anns:592
# scene-0796, Scooter, peds on sidewalk, bus, cars, t... [18-10-02 02:52:24]   20s, singapore-queensto, #anns:708
# scene-0916, Parking lot, bicycle rack, parked bicyc... [18-10-08 07:37:13]   20s, singapore-queensto, #anns:2387
# scene-1077, Night, big street, bus stop, high speed... [18-11-21 11:39:27]   20s, singapore-hollandv, #anns:890
# ...

# %%
my_scene =  nusc.scene[0]
my_scene
# Out:
# {'token': 'cc8c0bf57f984915a77078b10eb33198',
#  'log_token': '7e25a2c8ea1f41c5b0da1e69ecfa71a2',
#  'nbr_samples': 39,
#  'first_sample_token': 'ca9a282c9e77460f8360f564131a8af5',
#  'last_sample_token': 'ed5fc18c31904f96a8f0dbb99ff069c0',
#  'name': 'scene-0061',
#  'description': 'Parked truck, construction, intersection, turn left, following a van'}

# %%
sample_token = my_scene['first_sample_token']
sample_token
# Out:
# 'ca9a282c9e77460f8360f564131a8af5'

# %%
my_sample = nusc.get('sample', sample_token)
my_sample
# Out:
# {'token': 'ca9a282c9e77460f8360f564131a8af5',
#  'timestamp': 1532402927647951,
#  'prev': '',
#  'next': '39586f9d59004284a7114a68825e8eec',
#  'scene_token': 'cc8c0bf57f984915a77078b10eb33198',
#  'data': {'RADAR_FRONT': '37091c75b9704e0daa829ba56dfa0906',
#   'RADAR_FRONT_LEFT': '11946c1461d14016a322916157da3c7d',
#   'RADAR_FRONT_RIGHT': '491209956ee3435a9ec173dad3aaf58b',
#   'RADAR_BACK_LEFT': '312aa38d0e3e4f01b3124c523e6f9776',
#   'RADAR_BACK_RIGHT': '07b30d5eb6104e79be58eadf94382bc1',
#   'LIDAR_TOP': '9d9bf11fb0e144c8b446d54a8a00184f',
#   'CAM_FRONT': 'e3d495d4ac534d54b321f50006683844',
#   'CAM_FRONT_RIGHT': 'aac7867ebf4f446395d29fbd60b63b3b',
#   'CAM_BACK_RIGHT': '79dbb4460a6b40f49f9c150cb118247e',
#   'CAM_BACK': '03bea5763f0f4722933508d5999c5fd8',
#   'CAM_BACK_LEFT': '43893a033f9c46d4a51b5e08a67a1eb7',
#   'CAM_FRONT_LEFT': 'fe5422747a7d4268a4b07fc396707b23'},
#  'anns': ['ef63a697930c4b20a6b9791f423351da',
#   '6b89da9bf1f84fd6a5fbe1c3b236f809',
# ...

# %%
my_lidar_sample = nusc.get('sample_data', my_sample['data']['LIDAR_TOP'] )
my_lidar_sample
# Out:
# {'token': '9d9bf11fb0e144c8b446d54a8a00184f',
#  'sample_token': 'ca9a282c9e77460f8360f564131a8af5',
#  'ego_pose_token': '9d9bf11fb0e144c8b446d54a8a00184f',
#  'calibrated_sensor_token': 'a183049901c24361a6b0b11b8013137c',
#  'timestamp': 1532402927647951,
#  'fileformat': 'pcd',
#  'is_key_frame': True,
#  'height': 0,
#  'width': 0,
#  'filename': 'samples/LIDAR_TOP/n015-2018-07-24-11-22-45+0800__LIDAR_TOP__1532402927647951.pcd.bin',
#  'prev': '',
#  'next': '0cedf1d2d652468d92d23491136b5d15',
#  'sensor_modality': 'lidar',
#  'channel': 'LIDAR_TOP'}

# %%
my_calibrated_sensor_token = my_lidar_sample['calibrated_sensor_token']
nusc.get('calibrated_sensor', my_calibrated_sensor_token )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 2
#       1 my_calibrated_sensor_token = my_lidar_sample['calibrated_sensor_token']
# ----> 2 nusc.get('sample_data', my_calibrated_sensor_token )
#
# File d:\project\LiDAR-GPT\.venv\lib\site-packages\nuscenes\nuscenes.py:219, in NuScenes.get(self, table_name, token)
#     211 """
#     212 Returns a record from table in constant runtime.
#     213 :param table_name: Table name.
#     214 :param token: Token of the record.
#     215 :return: Table record. See README.md for record details for each table.
#     216 """
#     217 assert table_name in self.table_names, "Table {} not found".format(table_name)
# --> 219 return getattr(self, table_name)[self.getind(table_name, token)]
#
# File d:\project\LiDAR-GPT\.venv\lib\site-packages\nuscenes\nuscenes.py:228, in NuScenes.getind(self, table_name, token)
# ...

# %%
my_next_lidar_sample = nusc.get('sample_data', '0cedf1d2d652468d92d23491136b5d15')
my_next_lidar_sample
# Out:
# {'token': '0cedf1d2d652468d92d23491136b5d15',
#  'sample_token': '39586f9d59004284a7114a68825e8eec',
#  'ego_pose_token': '0cedf1d2d652468d92d23491136b5d15',
#  'calibrated_sensor_token': 'a183049901c24361a6b0b11b8013137c',
#  'timestamp': 1532402927697752,
#  'fileformat': 'pcd',
#  'is_key_frame': False,
#  'height': 0,
#  'width': 0,
#  'filename': 'sweeps/LIDAR_TOP/n015-2018-07-24-11-22-45+0800__LIDAR_TOP__1532402927697752.pcd.bin',
#  'prev': '9d9bf11fb0e144c8b446d54a8a00184f',
#  'next': '0865d9cca7f647c3a2d37f9ba7a2d7f4',
#  'sensor_modality': 'lidar',
#  'channel': 'LIDAR_TOP'}

# %%
import json
nusc_qa_path = '../../data/nuscenesQA/NuScenes_train_questions.json'
with open(nusc_qa_path, 'r') as f:
    qa_raw_data = json.load(f) 
    
qa_list = qa_raw_data['questions'] 
print(len(qa_list))
# Out:
# 376604

# %%
print(qa_list[0])
# Out:
# {'split': 'train', 'sample_token': 'e93e98b63d3b40209056d129dc53ceee', 'question': 'There is a car to the back right of me; what status is it?', 'answer': 'moving', 'num_hop': 1, 'template_type': 'status'}

# %%
import numpy as np

# %%
# %ls ..\..\data\nuscenes\samples\LIDAR_TOP
# Out:
#  Volume in drive D is Data
#  Volume Serial Number is FE40-D14E
#
#  Directory of d:\project\LiDAR-GPT\data\nuscenes\samples\LIDAR_TOP
#
# 18/03/2019  01:19    <DIR>          .
# 18/03/2019  01:15    <DIR>          ..
# 18/03/2019  01:16           695,040 n008-2018-08-01-15-16-36-0400__LIDAR_TOP__1533151603547590.pcd.bin
# 18/03/2019  01:16           693,760 n008-2018-08-01-15-16-36-0400__LIDAR_TOP__1533151604048025.pcd.bin
# 18/03/2019  01:16           695,040 n008-2018-08-01-15-16-36-0400__LIDAR_TOP__1533151604547893.pcd.bin
# 18/03/2019  01:16           694,400 n008-2018-08-01-15-16-36-0400__LIDAR_TOP__1533151605047769.pcd.bin
# 18/03/2019  01:16           695,680 n008-2018-08-01-15-16-36-0400__LIDAR_TOP__1533151605548192.pcd.bin
# 18/03/2019  01:16           694,400 n008-2018-08-01-15-16-36-0400__LIDAR_TOP__1533151606048630.pcd.bin
# 18/03/2019  01:16           693,760 n008-2018-08-01-15-16-36-0400__LIDAR_TOP__1533151606549066.pcd.bin
# ...

# %%
print(np.fromfile('D:/project/LiDAR-GPT/data/nuscenes/samples/LIDAR_TOP/n008-2018-08-01-15-16-36-0400__LIDAR_TOP__1533151603547590.pcd.bin', dtype=np.float32).shape)
# Out:
# (173760,)

# %%
sample_token
# Out:
# 'ca9a282c9e77460f8360f564131a8af5'
